# %%
#1 preprocessing

import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# Set random seed for reproducibility
np.random.seed(42)

# Generate synthetic data (10 samples, 5 features)
data = np.random.randint(0, 255, (10, 5))

# Initialize MinMaxScaler (scales between 0 and 1 by default)
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data)

# Display original and scaled data
print("🔹 Original Data:\n", data)
print("\n🔹 Scaled Data (0-1 range):\n", scaled_data)

# --- Visualization ---
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Plot original data
axes[0].imshow(data, cmap="viridis", aspect="auto")
axes[0].set_title("Original Data")
axes[0].set_xlabel("Features")
axes[0].set_ylabel("Samples")

# Plot scaled data
axes[1].imshow(scaled_data, cmap="viridis", aspect="auto")
axes[1].set_title("Scaled Data (0 - 1)")
axes[1].set_xlabel("Features")
axes[1].set_ylabel("Samples")

plt.suptitle("Min-Max Scaling Transformation", fontsize=14, fontweight="bold")
plt.tight_layout()
plt.show()
# Out:
# 🔹 Original Data:
#  [[102 179  92  14 106]
#  [ 71 188  20 102 121]
#  [210 214  74 202  87]
#  [116  99 103 151 130]
#  [149  52   1  87 235]
#  [157  37 129 191 187]
#  [ 20 160 203  57  21]
#  [252 235  88  48 218]
#  [ 58 254 169 219 187]
#  [207  14 189 189 174]]
#
# 🔹 Scaled Data (0-1 range):
#  [[0.35344828 0.6875     0.45049505 0.         0.39719626]
#  [0.21982759 0.725      0.09405941 0.42926829 0.46728972]
#  [0.81896552 0.83333333 0.36138614 0.91707317 0.30841121]
#  [0.4137931  0.35416667 0.5049505  0.66829268 0.50934579]
#  [0.55603448 0.15833333 0.         0.35609756 1.        ]
#  [0.59051724 0.09583333 0.63366337 0.86341463 0.77570093]
#  [0.         0.60833333 1.         0.2097561  0.        ]
#  [1.         0.92083333 0.43069307 0.16585366 0.92056075]
#  [0.1637931  1.         0.83168317 1.         0.77570093]
#  [0.80603448 0.         0.93069307 0.85365854 0.71495327]]
